# %% [markdown]
# # Репрезентация текста в ML-моделях

# %% [markdown]
# ![](https://pbs.twimg.com/media/EZlnU2oXsAEMUSP?format=jpg&name=4096x4096)

# %% [markdown]
# В первом модуле мы научились предобрабатывать тексты: лемматизировать, выделять морфологическую информацию, создавать семантические векторы с помощью w2v-моделей, записывать полученную информацию в датафрейм. Тем не менее, модели машинного обучения плохо понимают тексты — гораздо лучше они справляется с цифрами.
#
# Способов **векторизации** текста (то есть перехода от _слов_ к _значащим числам_ ) есть несколько. Сегодня мы рассмотрим TF-IDF.

# %% [markdown]
# ## Как вообще можно представлять текст?

# %% [markdown]
# Основных способов на самом деле два: мешок слов / bag of words и использование эмбеддингов.
#
# ---
#
# **Мешок слов** — способ, основанный на подсчёте частотностей слов в конкретном корпусе.
#
# <font style="color:green">Плюсы:</font> учитывает нюансы вашей коллекции текстов; проще для понимания.
#
# <font style="color:red">Минусы:</font> нужно готовить самому; если в вашей коллекции появится новый документ с новыми словами, с ним будет трудно — придётся всё пересчитывать.
#
# ---
#
# **Эмбеддинги** — заранее предобученные готовые модели, которые могут конвертировать ваш текст в вектор.
#
# <font style="color:green">Плюсы:</font> быстро; универсально.
#
# <font style="color:red">Минусы:</font> модели занимают много места; иногда от модели зависит итоговый вектор и она сильно влияет на качество.

# %% [markdown]
# ## TF-IDF
#
# Одна из самых популярных метрик — TF-IDF. Она не только учитывает все слова в тексте, но и принимает во внимание их важность.
#
# ### TF
#
# В этой аббревиатуре TF обозначает **text frequency** — сколько раз слово (а вернее, «терм») встретилось в документе. Считается просто — количество раз, которое слово встретилось, делённое на общее количество слов в тексте:
#
# $$TF_{i,j} = \frac{n_{i,j}}{\sum_{k}^{}n_{i,j}}$$

# %% [markdown]
# ### IDF
#
# IDF — это **inverse document frequency** — важность терма для конкретного документа. Он считается так:
#
# $$ IDF = log \frac{N}{n_t}$$
#
# — общее количество документов делится на количество документов, где нужный терм встретился хотя бы один раз; от полученной величины берётся логарифм. Таким образом, если терм встретился только в одном документе, то его IDF будет высокой (=> это важный для документа терм).

# %% [markdown]
# ### Общая мера
#
# Итоговая величина получается перемножением исходных двух метрик:
#
# $$TFIDF = TF \cdot IDF$$

# %% [markdown]
# ### Как это работает?
#
# Возьмём два текста:
#
# * `Мама мыла раму`
#
# * `Даша мыла яблоки`
#
# — всего в них 5 уникальных слов.
#
# Получается матрица 5 (слов) x 2 (документа):
#
# ||мама|мыла|раму|даша|яблоки|
# |:--:|:--:|:--:|:--:|:--:|:--:|
# |документ 1||||||
# |документ 2||||||

# %% [markdown]
# Посчитаем TF:
#
# ||мама|мыла|раму|даша|яблоки|
# |:--:|:--:|:--:|:--:|:--:|:--:|
# |документ 1|1/3|1/3|1/3|0|0|
# |документ 2|0|1/3|0|1/3|1/3|

# %% [markdown]
# Посчитаем IDF:
#
# ||мама|мыла|раму|даша|яблоки|
# |:--:|:--:|:--:|:--:|:--:|:--:|
# |документ 1|$log(2/1)$|$log(2/2)$|$log(2/1)$|||
# |документ 2||$log(2/2)$||$log(2/1)$|$log(2/1)$|

# %% [markdown]
# Перемножаем:
#
# ||мама|мыла|раму|даша|яблоки|
# |:--:|:--:|:--:|:--:|:--:|:--:|
# |документ 1|0.231|0|0.231|0|0|
# |документ 2|0|0|0|0.231|0.231|

# %% [markdown]
# Соответственно, документ 1 описывается вектором `[0.231, 0, 0.231, 0, 0]`, а документ 2 — `[0, 0, 0, 0.231, 0.231]`.

# %% [markdown]
# ### Что важно помнить при подсчёте TF-IDF?
#
# **Преобработанный текст**
#
# Ваш текст уже должен быть избавлен от знаков препинания, неуместных заглавных букв и т.д., а также лемматизирован. Так вы избавитесь от разных «термов»-форм слова, которые значат по сути одно и то же.
#
# **Стоп-слова**
#
# При работе с TF-IDF матрицей лучше убирать из текста стоп-слова: их высокая частотность и присутствие во многих документах может размыть вам картинку.

# %% [markdown]
# ### Реализация TF-IDF
#
# …уже сделана за нас в пакете sklearn.

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
stops = stopwords.words("russian")

tfidf = TfidfVectorizer(
    analyzer="word", # анализировать по словам или по символам (char)
    stop_words=stops # передаём список стоп-слов для русского из NLTK
)

# %% [markdown]
# ## Практика

# %% [markdown]
# Загрузим данные из некоторой заполярной газеты:

# %%
import os

# %%
path_to_articles = "./data/polar_circle"
articles = [os.path.join(path_to_articles, item) 
            for item in os.listdir(path_to_articles)
            if item.endswith(".txt")]

# %%
articles_texts = []

for article_path in articles:
    with open(article_path, "r", encoding="utf-8") as a_src:
        # первые 6 строк — метаданные, последняя — число комментариев
        articles_texts.append("\n".join(a_src.readlines()[6:-1]))

# %% [markdown]
# Лемматизируем:

# %%
from nltk.tokenize import wordpunct_tokenize
from pymorphy2 import MorphAnalyzer

# %%
morph = MorphAnalyzer()

# %%
articles_preprocessed = []
for a_text in articles_texts:
    a_tokens = wordpunct_tokenize(a_text)
    a_lemmatized = " ".join([morph.parse(item)[0].normal_form for item in a_tokens])
    articles_preprocessed.append(a_lemmatized)

# %% [markdown]
# Пропускаем через TF-IDF:

# %%
articles_tfidf = tfidf.fit_transform(articles_preprocessed)
print(f"Матрица на {articles_tfidf.shape[0]} документов и {articles_tfidf.shape[1]} термов")
# Out:
# Матрица на 25 документов и 2283 термов

# %% [markdown]
# При помощи метода `tfidf.get_feature_names()` можно посмотреть, какие именно термы есть в вашей матрице (здесь этого не будет, т.к. термов очень много).

# %%
# проверим, правда ли 2000+ термов
len(tfidf.get_feature_names())
# Out:
# 2283

# %% [markdown]
# ## А делать-то с этим что?
#
# Вариант 1: **машинное обучение**. Полученную матрицу можно засунуть в ML-модель для предсказания чего бы то ни было.
#
# ![](https://i.pinimg.com/originals/1e/11/31/1e1131d4cac5a6afb49580dab10aa281.jpg)

# %% [markdown]
# Вариант 2: **keyword extraction на коленке**.
#
# Задача _извлечения ключевых слов_ (keyword extraction) заключается в том, чтобы описать текст некоторым количеством слов, которые максимально точно передают его содержание. Попробуем написать функцию, которая для каждого ряда будет брать N слов с наибольшим TF-IDF и выводить их.

# %%
import numpy as np

# %%
def get_top_tf_idf_words(tfidf_vector, feature_names, top_n):
    sorted_nzs = np.argsort(tfidf_vector.data)[:-(top_n+1):-1]
    return feature_names[tfidf_vector.indices[sorted_nzs]]

# %%
feature_names = np.array(tfidf.get_feature_names())

for i, article in enumerate(articles_texts):
    # напечатаю только первые 5 статей
    if i < 5:
        article_vector = articles_tfidf[i, :]
        words = get_top_tf_idf_words(article_vector, feature_names, 10)
        print(article)
        print(words)
# Out:
# В городской администрации прошло очередное заседание антинаркотической комиссии.
#
# Важнейшей темой обсуждения стало состояние наркоситуации в городе, работа по предупреждению, выявлению и раскрытию преступлений, связанных с незаконным оборотом наркотиков на территории города.
#
# По аналитическим данным, озвученным временно исполняющим обязанности начальника полиции ОМВД России по городу Салехарду Андреем Печёнкиным, за первое полугодие этого года на профилактический учёт поставлено 27 человек. В прошлом году за такой же период – на десять больше. По мнению специалистов, снижению способствует и активизация борьбы с распространением наркотиков, и расширение судебной практики в отношении лиц, занимающихся распространением. А также профилактические мероприятия. В то же время происходит рост числа граждан, употребляющих наркотические вещества (токсикомания). За первое полугодие под наблюдение взято 11 человек, большинство из них подростки.
#
# Правоохранительными органами с начала года в городе выявлено и зарегистрировано 30 преступлений, связанных с незаконным оборотом наркотиков, в том числе за сбыт – 19. На учёте состоят 95 граждан. Всего изъято около полутора килограммов наркотических средств, большая часть из которых синтетические. Именно этот вид наркотиков, по словам правоохранителей, является преобладающим в окружной столице. Преимущественным видом сбыта синтетических наркотиков является так называемый бесконтактный способ – по сети Интернет.
#
# По информации специалистов управления МВД России по ЯНАО, на территории всего округа за семь месяцев текущего года выявлено и зарегистрировано 401 преступление, связанное с незаконным оборотом наркотиков. Изъято более десяти килограммов психоактивных веществ, большая часть которых синтетического происхождения. Новые виды веществ в этом году найдены не были.
#
# Правоохранительными органами в суд были направлены уголовные дела в отношении трёх преступных групп, занимавшихся сбытом в сети Интернет по территории городов Ноябрьск и Муравленко. Две из них являются организованными. Кроме этого, пресечена деятельность двоих оптовых поставщиков синтетики.
#
# На пропаганду здорового образа жизни и борьбу с пагубными привычками в Салехарде направлен целый ряд городских мероприятий. Профилактическая работа носит как системный характер, так и точечный. К примеру, не реже одного раза в месяц участковыми уполномоченными полиции проводятся беседы о вреде наркотических средств в трудовых коллективах и образовательных учреждениях. Проводятся рейдовые мероприятия, идёт работа с неблагополучными семьями, состоящими на профилактическом учёте. К активному пропагандированию здорового образа жизни подключилось и волонтёрское объединение «Радуга», которое действует на базе средней школы №2 уже пять лет. Главная задача активистов – на личном примере показать, как можно сохранить здоровье. Ребята активно участвуют как в городских акциях, так и проводят мероприятия на базе своего учреждения. Сегодня в городе зарегистрировано и действует несколько волонтёрских объ­единений. В них порядка 200 молодых людей, среди которых есть и ребята, состоявшие ранее на учёте в комиссии по делам несовершеннолетних. Значительную роль в профилактике наркомании играет также информационно-просветительская деятельность и целенаправленная работа в средствах массовой информации.
#
# ['наркотик' 'профилактический' 'учёт' 'мероприятие' 'наркотический' 'сбыт'
#  'оборот' 'зарегистрировать' 'незаконный' 'связанный']
# В окружной столице состоялось внеочередное заседание Территориальной избирательной комиссии по городу Салехард.
#
# На заседании рассмотрели вопрос о регистрации депутата Тюменской областной Думы шестого созыва, избранного по Салехардскому одномандатному избирательному округу №1 – Сергея Корепанова. Собравшиеся заслушали проект решения и единогласно проголосовали за его принятие.
#
# – На основании решения городской территориальной избирательной комиссии об определении результатов выборов депутатов Тюменской областной Думы шестого созыва по одномандатному избирательному округу №1 по городу Салехард принято решение о регистрации Сергея Корепанова в качестве депутата Тюменской областной Думы шестого созыва. Выдать ему удостоверение депутата Тюменской областной Думы, а также направить настоящее решение в избирательную комиссию Тюменской области, – зачитал документ председатель территориальной избирательной комиссии по городу Салехард Иван Сырков.
#
# Так как сам вновь избранный депутат не смог принять участие в заседании комиссии, принято решение передать ему удостоверение. Лично в руки.
#
# ['избирательный' 'тюменский' 'решение' 'депутат' 'областной' 'комиссия'
#  'дума' 'принять' 'территориальный' 'созыв']
# В Салехардском центре молодёжи подвели итоги проекта «Трудовое лето-2016» и открыли новый творческий сезон.
#
# В летние каникулы около 500 школьников от 14 до 18 лет работали на благо родного города. Подростки попробовали свои силы в качестве помощников почтальона, курьера, библиотекаря, делопроизводителя, убирали улицы, ухаживали за клумбами. В этом году – рекордное количество работодателей – 26. Среди них – Почта России, АО «Салехардэнерго», Муниципальное автотранспортное предприятие, ООО «Цезарь», департамент образования города. За трудовую смену каждый школьник заработал около 12,5 тысяч рублей.
#
# Девять подростков трудились этим летом в редакции газеты «Полярный круг» и помогали её коллективу в выпуске очередного номера. Ребята были курьерами, работали с документами, архивом. Никита Андреев попробовал себя в роли корреспондента и написал в рамках регионального проекта «Спасибо, доктор!» статью о своей бабушке Алевтине Васильевой – операционной сестре.
#
# Первый заместитель главы городской администрации Евгений Семихин вручил самым трудолюбивым ребятам – около 20 человек – благодарственные письма и сувениры от имени градоначальника Ивана Кононенко. Он поблагодарил руководителей предприятий и организаций, где работали подростки.
#
# – Чем больше возможностей мы дадим молодёжи сейчас, тем больше отдачи получим в будущем. Это наши трудовые ресурсы, которые мы куём уже сегодня. Результат вашего труда – это то пространство, которое вы формируете вокруг себя. Благодаря вашим стараниям город, в котором мы живём, стал уютнее, красивее, чище. Спасибо вам! – обратился к юным салехардцам Евгений Викторович.
#
# Одна из награждённых – десятиклассница Екатерина Косачева. Она участвовала в проекте впервые. В июне девушка работала в гостинице «Полярный круг» помощником делопроизводителя, совмещая трудовую деятельность с подготовкой к экзаменам.
#
# – Мне всё очень понравилось! Большое спасибо коллективу, это очень дружелюбные люди, которые во всём старались помочь, никогда ни в чём не отказывали. Хотелось бы поработать там ещё, – говорит Екатерина.
#
# Уже второй год подряд её ровесница Каролина Федорец занималась в летний период уборкой улиц. Говорит, что очень приятно идти потом по чистому городу и видеть в этом свой вклад. Да и деньги на карманные расходы просить у мамы не всегда хочется – заработать самой гораздо лучше.
#
# Вместе с закрытием трудового сезона стартовал творческий. Участники клубных формирований и друзья Салехардского центра молодёжи приготовили по этому случаю эффектное зрелище – концерт.
#
# ['трудовой' 'работать' 'это' 'молодёжь' 'подросток' 'спасибо' 'очень'
#  'сезон' 'евгений' 'заработать']
# Женщина осуждена за угрозу убийством.
#
# В июне этого года между двумя пожилыми женщинами произошёл словесный конфликт, из-за которого одна из них – гражданка Д., 1947 года рождения, схватила нож и стала угрожать потерпевшей. Для создания видимости реальной угрозы женщина несколько раз ударила остриём ножа по столу. В сложившейся ситуации потерпевшая имела все основания опасаться за свою жизнь и здоровье.
#
# ['угроза' 'женщина' 'потерпевший' 'нож' 'конфликт' 'пожилое' 'сложиться'
#  'остриё' 'реальный' 'угрожать']
# По обращению бывшего работника ООО «Вершина» прокуратура города провела проверку соблюдения трудового законодательства.
#
# Установлено, что в организации с февраля по июнь этого года образовалась задолженность по заработной плате в размере 403 тысяч рублей. Так, директору организации вынесено представление и возбуждены дела об административном правонарушении – нарушение трудового законодательства.
#
# В интересах заявителя 16 сентября в мировой суд направлено заявление о выдаче судебного приказа о взыскании начисленной, но невыплаченной заработной платы.
#
# Акты реагирования находятся на рассмотрении. Исполнение приказа в данной организации в полном объёме находится на контроле прокуратуры города.
#
# ['плата' 'приказ' 'заработный' 'организация' 'законодательство'
#  'прокуратура' 'трудовой' 'находиться' 'начислить' 'взыскание']
